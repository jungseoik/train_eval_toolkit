# %%
from google import genai
from google.genai import types
ENV_AUTH_V2 = "REDACTED_API_KEY"

import os

class GeminiImageAnalyzer:
    def __init__(self, model_name: str = "gemini-3-flash-preview", project: str = "gmail-361002", location: str = "us-central1"):
        os.environ['GEMINI_API_KEY'] = ENV_AUTH_V2
        self.client = genai.Client()
        self.model_name = model_name
        self.whole_response = None

    def analyze_image(self, image_path: str, custom_prompt: str = "explain this image") -> str:
        """
        이미지 분석을 수행합니다.
        
        Args:
            image_path (str): 분석할 이미지 경로
            custom_prompt (str): 커스텀 프롬프트 (선택사항)
        
        Returns:
            str: 분석 결과
        """
        try:
            with open(image_path, "rb") as f:
                image_bytes = f.read()
            response = self.client.models.generate_content(
                model=self.model_name,
                contents=[
                    types.Part.from_bytes(data=image_bytes, mime_type="image/jpeg"),
                    custom_prompt
                ]
            )
            self.whole_response = response
            return response.text.strip()
        except Exception as e:
            return f"❌ gemini 오류 발생 ({self.model_name}): {str(e)}"
    def analyze_video(
        self,
        video_path: str,
        custom_prompt: str = "explain this video",
        mime_type: str  = "video/mp4",
    ) -> str:
        """
        비디오 분석
        
        Args:
            video_path (str): 분석할 비디오 경로
            custom_prompt (str): 커스텀 프롬프트 (선택, 기본: PROMPT_VIDEO)
            mime_type (str | None): 강제 MIME 타입 지정 (미지정 시 확장자로 추정, 기본값 video/mp4)
        Returns:
            str: 분석 결과 텍스트
        """
        try:
            with open(video_path, "rb") as f:
                video_bytes = f.read()

            response = self.client.models.generate_content(
                model=self.model_name,
                contents=types.Content(
                    parts=[
                        types.Part(
                            inline_data=types.Blob(data=video_bytes, mime_type=mime_type)
                        ),
                        types.Part(text=custom_prompt)
                    ]
                )
            )
            self.whole_response = response
            return response.text.strip()
        except Exception as e:
            return f"❌ gemini 오류 발생 ({self.model_name}): {str(e)}"




g = GeminiImageAnalyzer()
# rep = g.analyze_image('/mnt/nas_192/datasets/projects/gangnam_innovation/violence_fintuning/TADO_Violence_GangNAM/1.png' , custom_prompt="이미지에 대해 설명해봐")
rep = g.analyze_video('/mnt/nas_192/datasets/projects/gangnam_innovation/violence_fintuning/TADO_Violence_GangNAM/data/processed/ABB_banwoldang/PE/Test/falldown/raw/ec_10_15-16_upstation_bottom_up_falldown_3.mp4' , custom_prompt="비디오에 대해 설명해봐")
print(rep)
# Out:
# ...
# 2023년 9월 26일 오후 1시 4분경, 지하철역 10번 출구 에스컬레이터(B1)에서 한 남성이 넘어지는 사고가 발생한 영상입니다.
#
# 영상 초반, 녹색 조끼와 흰색 모자를 쓴 남성이 먼저 에스컬레이터에서 안전하게 내립니다. 그 뒤를 이어 내려오던 검은색 옷을 입은 남성이 에스컬레이터 끝부분에서 중심을 잃고 바닥에 완전히 엎어지며 넘어집니다.
#
# 넘어진 남성은 약 5~6초 동안 바닥에 엎드린 채 움직이지 못하다가, 서서히 손을 짚고 몸을 일으킵니다. 다행히 스스로 일어난 남성은 몸을 추스르며 화면 왼쪽 하단으로 걸어 나갑니다. 이후 뒤따라오던 다른 승객이 에스컬레이터에서 내리는 모습으로 영상이 끝납니다.

# %%
print(g.whole_response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""2023년 9월 26일 오후 1시 4분경, 지하철역 10번 출구 에스컬레이터(B1)에서 한 남성이 넘어지는 사고가 발생한 영상입니다.
#
# 영상 초반, 녹색 조끼와 흰색 모자를 쓴 남성이 먼저 에스컬레이터에서 안전하게 내립니다. 그 뒤를 이어 내려오던 검은색 옷을 입은 남성이 에스컬레이터 끝부분에서 중심을 잃고 바닥에 완전히 엎어지며 넘어집니다.
#
# 넘어진 남성은 약 5~6초 동안 바닥에 엎드린 채 움직이지 못하다가, 서서히 손을 짚고 몸을 일으킵니다. 다행히 스스로 일어난 남성은 몸을 추스르며 화면 왼쪽 하단으로 걸어 나갑니다. 이후 뒤따라오던 다른 승객이 에스컬레이터에서 내리는 모습으로 영상이 끝납니다.""",
#         thought_signature=b"\x12\xf7\x14\n\xf4\x14\x01r\xc8\xda|q\x0f\xfbb\xe0\xff9N\xe4\x18y \xe25\xb6\xd8@\xad?[C@\xf1\xd5\xced\x02\xbd8>\xfe\xa8c\x8b\xf9\x9b\x8dh\xee\x05\x0f\x93\x17\xf3a9ch+\xff\x96lzG\xed3N/n\x15F\\\xf6\xd6z\xa6p\xd7\xd4\xd9l\x11T]\xee\x0f[\x84\xb6L>\xe5R'\xe6\xc3...'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# ...
